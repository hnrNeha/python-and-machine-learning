# %%
import pandas as pd
mf=pd.read_csv(r'C:\Users\hnrne\Downloads\AB_NYC_2019.csv')
mf.columns=mf.columns.str.upper()
print(mf)
print(mf.isnull())
# Out:
#              ID                                               NAME   HOST_ID  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
mf.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of           ID   NAME  HOST_ID  HOST_NAME  NEIGHBOURHOOD_GROUP  NEIGHBOURHOOD  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# ...

# %%
mf.head()
# Out:
#      ID                                              NAME  HOST_ID  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      HOST_NAME NEIGHBOURHOOD_GROUP NEIGHBOURHOOD  LATITUDE  LONGITUDE  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          ROOM_TYPE  PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS LAST_REVIEW  \
# ...

# %%
mf_with_0=mf.fillna(0)

# %%
mf_with_0.head()
# Out:
#      ID                                              NAME  HOST_ID  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      HOST_NAME NEIGHBOURHOOD_GROUP NEIGHBOURHOOD  LATITUDE  LONGITUDE  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          ROOM_TYPE  PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS LAST_REVIEW  \
# ...

# %%
mfr=mf.REVIEWS_PER_MONTH.fillna(mf['REVIEWS_PER_MONTH'].mean())

# %%
mf
# Out:
#              ID                                               NAME   HOST_ID  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
mf.REVIEWS_PER_MONTH.mean()
# Out:
# 1.3732214298586618

# %%
mfr
# Out:
# 0        0.210000
# 1        0.380000
# 2        1.373221
# 3        4.640000
# 4        0.100000
#            ...
# 48890    1.373221
# 48891    1.373221
# 48892    1.373221
# 48893    1.373221
# 48894    1.373221
# Name: REVIEWS_PER_MONTH, Length: 48895, dtype: float64

# %%
mfd=mf.dropna()

# %%
mfd.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 mfd.shape()
#
# TypeError: 'tuple' object is not callable

# %%
mfd.shape
# Out:
# (38821, 16)

# %%
mfd
# Out:
#              ID                                              NAME    HOST_ID  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
mfc=mf.dropna(how='any',thresh=2)

# %% [markdown]
# mfc.shape

# %%
mfc.shape
# Out:
# (48895, 16)

# %%
mfc.interpolate
# Out:
# <bound method NDFrame.interpolate of              ID                                               NAME   HOST_ID  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
mfd.interpolate
# Out:
# <bound method NDFrame.interpolate of              ID                                              NAME    HOST_ID  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
mfd=pd.write_csv(r'C:\Users\hnrne\Downloads\cleaned_AB_NYC_2019.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 mfd=pd.write_csv(r'C:\Users\hnrne\Downloads\cleaned_AB_NYC_2019.csv')
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\__init__.py:244, in __getattr__(name)
#     240     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     242     return _SparseArray
# --> 244 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'write_csv'

# %%
header=mfd.columns
data=mfd.rows
with open(r'C:\Users\hnrne\Downloads\cleaned_AB_NYC_2019.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 header=mfd.columns
# ----> 2 data=mfd.rows
#       3 with open(r'C:\Users\hnrne\Downloads\cleaned_AB_NYC_2019.csv', 'w', encoding='UTF8', newline='') as f:
#       4     writer = csv.writer(f)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py:5465, in NDFrame.__getattr__(self, name)
#    5463 if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464     return self[name]
# -> 5465 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
mfd.to_csv(r'C:\Users\hnrne\Downloads\cleaned_AB_NYC_2019.csv')

# %%
df=pd.read_csv(r'C:\Users\hnrne\Downloads\HealthCareAnalytics.csv')
df
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
df.isnull()
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0         False          False               False               False
# 1         False          False               False               False
# 2         False          False               False               False
# 3         False          False               False               False
# 4         False          False               False               False
# ...         ...            ...                 ...                 ...
# 318433    False          False               False               False
# 318434    False          False               False               False
# 318435    False          False               False               False
# 318436    False          False               False               False
# 318437    False          False               False               False
#
#         Hospital_region_code  Available_Extra_Rooms_in_Hospital  Department  \
# ...

# %%
df.dropna()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
df.dropna().interpolate
# Out:
# <bound method NDFrame.interpolate of         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
a=df.fillna(0)

# %%
a
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
dfa=a.dropna().interpolate

# %%
dfa
# Out:
# <bound method NDFrame.interpolate of         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
dfa.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 dfa.isnull().sum()
#
# AttributeError: 'function' object has no attribute 'isnull'

# %%
dfa.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 dfa.isnull()
#
# AttributeError: 'function' object has no attribute 'isnull'

# %%
dfa
# Out:
# <bound method NDFrame.interpolate of         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
df.isnull()
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0         False          False               False               False
# 1         False          False               False               False
# 2         False          False               False               False
# 3         False          False               False               False
# 4         False          False               False               False
# ...         ...            ...                 ...                 ...
# 318433    False          False               False               False
# 318434    False          False               False               False
# 318435    False          False               False               False
# 318436    False          False               False               False
# 318437    False          False               False               False
#
#         Hospital_region_code  Available_Extra_Rooms_in_Hospital  Department  \
# ...

# %%
a=df.fillna(0)

# %%
a
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
b=a.dropna()

# %%
b
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
df.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available_Extra_Rooms_in_Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed_Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type_of_Admission                       0
# Severity_of_Illness                     0
# Visitors_with_Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
a.isnull().sum()
# Out:
# case_id                              0
# Hospital_code                        0
# Hospital_type_code                   0
# City_Code_Hospital                   0
# Hospital_region_code                 0
# Available_Extra_Rooms_in_Hospital    0
# Department                           0
# Ward_Type                            0
# Ward_Facility_Code                   0
# Bed_Grade                            0
# patientid                            0
# City_Code_Patient                    0
# Type_of_Admission                    0
# Severity_of_Illness                  0
# Visitors_with_Patient                0
# Age                                  0
# Admission_Deposit                    0
# Stay                                 0
# dtype: int64

# %%
b.interpolate
# Out:
# <bound method NDFrame.interpolate of         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available_Extra_Rooms_in_Hospital    Department  \
# ...

# %%
b.to_csv(r'C:\Users\hnrne\Downloads\cleaned_HealthCareAnalytics.csv')

# %%
cf=pd.read_csv(r'C:\Users\hnrne\Downloads\hotel_bookings.csv')

# %%
cf.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
cf.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
d=cf.fillna(0)

# %%
d
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
m=d.dropna().interpolate

# %%
m
# Out:
# <bound method NDFrame.interpolate of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
m.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 m.isnull().sum()
#
# AttributeError: 'function' object has no attribute 'isnull'

# %%
d.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
d.to_csv(r'C:\Users\hnrne\Downloads\cleaned_hotel_bookings.csv')
